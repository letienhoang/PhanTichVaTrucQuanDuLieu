# %%
if 1 == 1:
    print("True")
else:
    print("False")

# %%
(1 + x for x in [1, 2, 3])
# Out:
# <generator object <genexpr> at 0x0000024151C81490>

# %%
def hama(*args):
    print(args)
    print(type(args))

hama("test")
# Out:
# ('test',)
# <class 'tuple'>

# %%
def hama2(**kwargs):
    print(kwargs)
    print(type(kwargs))

hama2(test="test")
# Out:
# {'test': 'test'}
# <class 'dict'>

# %%
(lambda x: 2*x + 1)(2)
# Out:
# 5

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
s = df['Price (VND)']
type(s)
# Out:
# pandas.Series

# %%
s1 = pd.Series(data=[2, 5, 9, 1, 5])
s2 = pd.Series(data=[True, False, True, True, False])

# %%
s1[s2]
# Out:
# 0    2
# 2    9
# 3    1
# dtype: int64
