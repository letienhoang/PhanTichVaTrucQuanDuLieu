# %% [markdown]
# ## 1. Kiểu số : int – float – int() – float()

# %%
# int
92
7121

# float
9.2
342.33
# Out:
# 342.33

# %% [markdown]
# ## 2. Kiểu chuỗi : str – str()

# %%
s1 = "Hello"
s2 = 'Moneyy'

# %% [markdown]
# ## 3. Kiểu danh sách : list – list()

# %%
sv = [369, 'Nguyễn Văn Mười', 7.8, 92]

# %% [markdown]
# ## 4. Kiểu tuple : tuple – tuple()

# %%
sv1 = (369, 'Nguyễn Văn Mười', 7.8, 92)

# %% [markdown]
# ## 5. Kiểu từ điển : dict – dict()

# %%
sv2 = {'Tuoi': 9999, 'Họ tên': 'Nguyễn Văn Mười', 'Điểm TB': 9.9, 'Mon': 'Ielts'}

# %% [markdown]
# ## 6. Kiểu tập hợp : set – set()

# %%
s = {34, 89, 'Python', 56, 9.5, 'Java'}

# %% [markdown]
# ## 7. Kiểu boolean : bool – bool()

# %%
a = True
b = False

# %% [markdown]
# ## 8. Kiểu None : None – NoneType

# %%
c = None

# %% [markdown]
# ## 9. Toán tử

# %%
8 + 5

2 - 3

2 * 3

7 / 22

74 // 22

7 % 2

2 ** 3

u = [8, 29, 212, 9921]

29 in u

27 not in u
# Out:
# True
